# %%
import pandas as pd

df = pd.read_csv("orders.csv")
print(df)
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
df.head()
# Out:
#    OrderID   CustomerName       Product     Category  Quantity   Price  \
# 0     1001     John Smith        Laptop  Electronics         1  1200.0
# 1     1002      Sarah Lee    Headphones  Electronics         2   150.0
# 2     1003       Ali Khan  Office Chair    Furniture         1   300.0
# 3     1004     Alice Wong     Desk Lamp    Furniture         3    45.0
# 4     1005  Carlos Mendez      Keyboard  Electronics         2    80.0
#
#     OrderDate Shipped    Country
# 0  2024-06-01     Yes        USA
# 1  2024-06-03      No     Canada
# 2  2024-06-04     Yes        UAE
# 3  2024-06-05     Yes  Singapore
# 4  2024-06-06      No     Mexico

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       40 non-null     int64
#  1   CustomerName  40 non-null     str
#  2   Product       40 non-null     str
#  3   Category      40 non-null     str
#  4   Quantity      40 non-null     int64
#  5   Price         40 non-null     float64
#  6   OrderDate     40 non-null     str
#  7   Shipped       40 non-null     str
#  8   Country       40 non-null     str
# dtypes: float64(1), int64(2), str(6)
# memory usage: 2.9 KB

# %%
df.tail()
# Out:
#     OrderID    CustomerName             Product     Category  Quantity  Price  \
# 35     1036   Emma Thompson  Desk Lamp with USB    Furniture         1   68.0
# 36     1037   Carlos Santos    Wireless Earbuds  Electronics         1  125.0
# 37     1038  Leila Mansouri            Desk Pad    Furniture         1   28.0
# 38     1039      Daniel Kim         Power Strip  Electronics         2   18.0
# 39     1040    Anna Ivanova          Desk Clock    Furniture         1   35.0
#
#      OrderDate Shipped      Country
# 35  2024-07-07      No           UK
# 36  2024-07-08     Yes     Portugal
# 37  2024-07-09     Yes         Iran
# 38  2024-07-10      No  South Korea
# 39  2024-07-11     Yes      Ukraine

# %%
df.columns
# Out:
# Index(['OrderID', 'CustomerName', 'Product', 'Category', 'Quantity', 'Price',
#        'OrderDate', 'Shipped', 'Country'],
#       dtype='str')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=40, step=1)

# %%
df["Category"]
# Out:
# 0     Electronics
# 1     Electronics
# 2       Furniture
# 3       Furniture
# 4     Electronics
# 5      Stationery
# 6       Furniture
# 7     Electronics
# 8      Stationery
# 9     Electronics
# 10    Electronics
# 11      Furniture
# 12     Stationery
# 13    Electronics
# 14      Furniture
# 15     Stationery
# 16    Electronics
# 17      Furniture
# 18    Electronics
# 19      Furniture
# 20     Stationery
# 21    Electronics
# 22      Furniture
# 23     Stationery
# 24    Electronics
# 25    Electronics
# 26      Furniture
# 27     Stationery
# 28    Electronics
# 29      Furniture
# 30    Electronics
# 31    Electronics
# 32      Furniture
# 33     Stationery
# 34    Electronics
# 35      Furniture
# 36    Electronics
# 37      Furniture
# 38    Electronics
# 39      Furniture
# Name: Category, dtype: str

# %%
df["Product"]
# Out:
# 0                    Laptop
# 1                Headphones
# 2              Office Chair
# 3                 Desk Lamp
# 4                  Keyboard
# 5                  Notebook
# 6             Standing Desk
# 7                   Monitor
# 8                       Pen
# 9                     Mouse
# 10                   Webcam
# 11             File Cabinet
# 12                  Stapler
# 13                USB Drive
# 14                Bookshelf
# 15            Printer Paper
# 16           Wireless Mouse
# 17           Desk Organizer
# 18               Calculator
# 19               Whiteboard
# 20             Highlighters
# 21        Bluetooth Speaker
# 22             Office Plant
# 23             Sticky Notes
# 24             Tablet Stand
# 25           Paper Shredder
# 26           Desk Chair Mat
# 27             Binder Clips
# 28        Wireless Keyboard
# 29            Desk Calendar
# 30                  USB Hub
# 31         Document Scanner
# 32    Desk Drawer Organizer
# ...

# %%
df[["Product", "Category", "Country"]]
# Out:
#                   Product     Category       Country
# 0                  Laptop  Electronics           USA
# 1              Headphones  Electronics        Canada
# 2            Office Chair    Furniture           UAE
# 3               Desk Lamp    Furniture     Singapore
# 4                Keyboard  Electronics        Mexico
# 5                Notebook   Stationery           UAE
# 6           Standing Desk    Furniture            UK
# 7                 Monitor  Electronics   South Korea
# 8                     Pen   Stationery         Italy
# 9                   Mouse  Electronics         Japan
# 10                 Webcam  Electronics        France
# 11           File Cabinet    Furniture         India
# 12                Stapler   Stationery     Australia
# 13              USB Drive  Electronics         Spain
# 14              Bookshelf    Furniture         China
# 15          Printer Paper   Stationery         Egypt
# 16         Wireless Mouse  Electronics        Poland
# ...

# %%
df.iloc[3]
# Out:
# OrderID               1004
# CustomerName    Alice Wong
# Product          Desk Lamp
# Category         Furniture
# Quantity                 3
# Price                 45.0
# OrderDate       2024-06-05
# Shipped                Yes
# Country          Singapore
# Name: 3, dtype: object

# %%
df[df["Category"] == "Electronics"]
# Out:
#     OrderID      CustomerName            Product     Category  Quantity  \
# 0      1001        John Smith             Laptop  Electronics         1
# 1      1002         Sarah Lee         Headphones  Electronics         2
# 4      1005     Carlos Mendez           Keyboard  Electronics         2
# 7      1008        James Park            Monitor  Electronics         2
# 9      1010  Takeshi Nakamura              Mouse  Electronics         1
# 10     1011     Sophie Martin             Webcam  Electronics         1
# 13     1014   Diego Rodriguez          USB Drive  Electronics         5
# 16     1017     Anna Kowalski     Wireless Mouse  Electronics         2
# 18     1019       Yuki Tanaka         Calculator  Electronics         1
# 21     1022    Isabella Silva  Bluetooth Speaker  Electronics         1
# 24     1025    Lucas Anderson       Tablet Stand  Electronics         1
# 25     1026      Chloe Dubois     Paper Shredder  Electronics         1
# ...

# %%
df.loc[df["Product"] == "Laptop"]
# Out:
#    OrderID CustomerName Product     Category  Quantity   Price   OrderDate  \
# 0     1001   John Smith  Laptop  Electronics         1  1200.0  2024-06-01
#
#   Shipped Country
# 0     Yes     USA

# %%
df.loc[df["Product"] == "Laptop"  , "CustomerName" ] = "Addo Emmanuel"

# %%
df.loc[df["Product"] == "Laptop"]
# Out:
#    OrderID   CustomerName Product     Category  Quantity   Price   OrderDate  \
# 0     1001  Addo Emmanuel  Laptop  Electronics         1  1200.0  2024-06-01
#
#   Shipped Country
# 0     Yes     USA

# %%
df.drop("CustomerName", axis=1, inplace=True)

# %%
df
# Out:
#     OrderID                Product     Category  Quantity   Price   OrderDate  \
# 0      1001                 Laptop  Electronics         1  1200.0  2024-06-01
# 1      1002             Headphones  Electronics         2   150.0  2024-06-03
# 2      1003           Office Chair    Furniture         1   300.0  2024-06-04
# 3      1004              Desk Lamp    Furniture         3    45.0  2024-06-05
# 4      1005               Keyboard  Electronics         2    80.0  2024-06-06
# 5      1006               Notebook   Stationery         5     5.0  2024-06-07
# 6      1007          Standing Desk    Furniture         1   450.0  2024-06-08
# 7      1008                Monitor  Electronics         2   220.0  2024-06-09
# 8      1009                    Pen   Stationery        10     1.5  2024-06-10
# 9      1010                  Mouse  Electronics         1    35.0  2024-06-11
# 10     1011                 Webcam  Electronics         1    85.0  2024-06-12
# ...

# %%
df.rename(columns={"OrderID" : "Order_ID"}, inplace= True)

# %%
df
# Out:
#     Order_ID                Product     Category  Quantity   Price  \
# 0       1001                 Laptop  Electronics         1  1200.0
# 1       1002             Headphones  Electronics         2   150.0
# 2       1003           Office Chair    Furniture         1   300.0
# 3       1004              Desk Lamp    Furniture         3    45.0
# 4       1005               Keyboard  Electronics         2    80.0
# 5       1006               Notebook   Stationery         5     5.0
# 6       1007          Standing Desk    Furniture         1   450.0
# 7       1008                Monitor  Electronics         2   220.0
# 8       1009                    Pen   Stationery        10     1.5
# 9       1010                  Mouse  Electronics         1    35.0
# 10      1011                 Webcam  Electronics         1    85.0
# 11      1012           File Cabinet    Furniture         2   180.0
# 12      1013                Stapler   Stationery         3    12.0
# ...

# %%
df.to_csv("data.csv", index=False)
